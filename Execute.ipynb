# %%
#imports the Neural Network model and runs it
import SentimentAnalysisNN
SentimentAnalysisNN.main()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mushahid/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Test accuracy of our model: 79.23%
#               precision    recall  f1-score   support
#
#            0      0.817     0.937     0.873      1836
#            1      0.681     0.469     0.556       601
#            2      0.776     0.648     0.706       491
#
#     accuracy                          0.792      2928
#    macro avg      0.758     0.685     0.712      2928
# weighted avg      0.782     0.792     0.780      2928

# %%
#imports the RNN model and runs it
import SentimentAnalysisRNN
SentimentAnalysisRNN.main()
# Out:
# Test accuracy of our model: 79.37%
#               precision    recall  f1-score   support
#
#            0      0.828     0.944     0.882      1836
#            1      0.645     0.453     0.532       601
#            2      0.774     0.650     0.707       491
#
#     accuracy                          0.794      2928
#    macro avg      0.749     0.682     0.707      2928
# weighted avg      0.781     0.794     0.781      2928
